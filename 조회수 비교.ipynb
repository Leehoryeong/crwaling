# %%
wassup = [44, 56, 59, 64, 87,  62,99, 78,69, 62,54,82,126,62,98,83,80,123,153,138]
chimchak = [2.6,7.9,7.2,2.6,11,8,15,8.5,13,5.6,9.1,4.2,13,3.6,22,10,12,5.3,6.6,20,4.1]

# %%
wassup=[138,153,123,80,83,98,62,126,82,54,62,69,78,99,62,87,64,59,56,44]
chimchak = [4.1,20,6.6,5.3,12,10,22,3.6,13,4.2,9.1,5.6,13,8.5,15,11,2.6,7.2,7.9,2.6]

# %%
import math

# %%
import numpy as np

# %%
print(np.mean(wassup[12:17]))
print(np.mean(chimchak[12:17]))
# Out:
# 78.0
# 10.02

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
no = np.arange(1,21)

# %%
my_dict = {'park':wassup,'mal':chimchak,'num':no}
my_df=pd.DataFrame(my_dict)

# %%
my_df
# Out:
#     park   mal  num
# 0    138   4.1    1
# 1    153  20.0    2
# 2    123   6.6    3
# 3     80   5.3    4
# 4     83  12.0    5
# 5     98  10.0    6
# 6     62  22.0    7
# 7    126   3.6    8
# 8     82  13.0    9
# 9     54   4.2   10
# 10    62   9.1   11
# 11    69   5.6   12
# 12    78  13.0   13
# 13    99   8.5   14
# 14    62  15.0   15
# 15    87  11.0   16
# 16    64   2.6   17
# 17    59   7.2   18
# 18    56   7.9   19
# 19    44   2.6   20

# %%
#stock_data['30일이평'] = stock_data['tradePrice'].rolling(window=30).mean()
my_df['3일이평_park'] = my_df['park'].rolling(window=3).mean()
my_df['3일이평_mal'] = my_df['mal'].rolling(window=3).mean()

# %%
my_df
# Out:
#     park   mal  num   3일이평_park   3일이평_mal
# 0    138   4.1    1         NaN        NaN
# 1    153  20.0    2         NaN        NaN
# 2    123   6.6    3  138.000000  10.233333
# 3     80   5.3    4  118.666667  10.633333
# 4     83  12.0    5   95.333333   7.966667
# 5     98  10.0    6   87.000000   9.100000
# 6     62  22.0    7   81.000000  14.666667
# 7    126   3.6    8   95.333333  11.866667
# 8     82  13.0    9   90.000000  12.866667
# 9     54   4.2   10   87.333333   6.933333
# 10    62   9.1   11   66.000000   8.766667
# 11    69   5.6   12   61.666667   6.300000
# 12    78  13.0   13   69.666667   9.233333
# 13    99   8.5   14   82.000000   9.033333
# 14    62  15.0   15   79.666667  12.166667
# 15    87  11.0   16   82.666667  11.500000
# 16    64   2.6   17   71.000000   9.533333
# 17    59   7.2   18   70.000000   6.933333
# 18    56   7.9   19   59.666667   5.900000
# 19    44   2.6   20   53.000000   5.900000

# %%
plt.plot(stock_data.loc[stock_data.golden==True].index,
         stock_data['5일이평'][stock_data.golden==True], 
         '^',c='gold')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager
[f.name for f in font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Serif Display',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'cmb10',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'cmsy10',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'cmr10',
#  'cmtt10',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmss10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  '?????',
#  'Haan YHead M',
#  'RixMGo M',
#  'Malgun Gothic',
#  'ahn2006-L',
#  'KoreanGSGGB',
#  'JejuGothic',
#  'MDotum',
#  'NanumSquareOTF',
#  'Yj SHANALL Medium ',
#  'YDIYGO340',
#  'OCR A Extended',
#  'Bell MT',
#  'Myriad Hebrew',
#  'Minion Pro',
# ...

# %%
plt.rc('font',family ='NEXON Football Gothic')

# %%
plt.plot(my_df.index,my_df['3일이평_park'],'g',label='박준형')
plt.plot(14.5,117,'^',c='gold',label="코카콜라 광고")


plt.legend(loc='best')
plt.xlabel("20개 컨텐츠")
plt.ylabel("조회수(만)")
plt.title("와썹맨 유튜브 조회수 추세")
# Out:
# Text(0.5,1,'와썹맨 유튜브 조회수 추세')

# %%
plt.plot(my_df.index,my_df['3일이평_mal'],'r',label='이말년')
plt.plot(14.5,8.0,'^',c='gold',label="코카콜라 광고")

plt.legend(loc='best')
plt.xlabel("20개 컨텐츠")
plt.ylabel("조회수(만)")
plt.title("침착맨 유튜브 조회수 추세")
# Out:
# Text(0.5,1,'침착맨 유튜브 조회수 추세')
